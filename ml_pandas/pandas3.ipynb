# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('spotify-2023.csv')
df.columns
df.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts    streams  in_apple_playlists  ...  bpm key   mode  \
# ...

# %%
df.describe()
# Out:
#        artist_count  released_year  released_month  released_day  \
# count    953.000000     953.000000      953.000000    953.000000
# mean       1.556139    2018.238195        6.033578     13.930745
# std        0.893044      11.116218        3.566435      9.201949
# min        1.000000    1930.000000        1.000000      1.000000
# 25%        1.000000    2020.000000        3.000000      6.000000
# 50%        1.000000    2022.000000        6.000000     13.000000
# 75%        2.000000    2022.000000        9.000000     22.000000
# max        8.000000    2023.000000       12.000000     31.000000
#
#        in_spotify_playlists  in_spotify_charts  in_apple_playlists  \
# count            953.000000         953.000000          953.000000
# mean            5200.124869          12.009444           67.812172
# std             7897.608990          19.575992           86.441493
# min               31.000000           0.000000            0.000000
# ...

# %%
# converting files to text file
txt = df.to_csv('spotify_txt',sep='\n',header=df.columns,index=None,na_rep='na',index_label="index")

# %% [markdown]
# <!-- understanding data using info() -->
# # Info About our Dataset

# %%
df.info(verbose=True,memory_usage=True,show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 953 entries, 0 to 952
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   track_name            953 non-null    object
#  1   artist(s)_name        953 non-null    object
#  2   artist_count          953 non-null    int64
#  3   released_year         953 non-null    int64
#  4   released_month        953 non-null    int64
#  5   released_day          953 non-null    int64
#  6   in_spotify_playlists  953 non-null    int64
#  7   in_spotify_charts     953 non-null    int64
#  8   streams               953 non-null    object
#  9   in_apple_playlists    953 non-null    int64
#  10  in_apple_charts       953 non-null    int64
#  11  in_deezer_playlists   953 non-null    object
#  12  in_deezer_charts      953 non-null    int64
#  13  in_shazam_charts      903 non-null    object
#  14  bpm                   953 non-null    int64
# ...

# %%
print("identifyig shape of our dataframe")
print(df.shape)

print(df.columns.to_list())
columns = df.columns.to_list()
# Out:
# identifyig shape of our dataframe
# (953, 24)
# ['track_name', 'artist(s)_name', 'artist_count', 'released_year', 'released_month', 'released_day', 'in_spotify_playlists', 'in_spotify_charts', 'streams', 'in_apple_playlists', 'in_apple_charts', 'in_deezer_playlists', 'in_deezer_charts', 'in_shazam_charts', 'bpm', 'key', 'mode', 'danceability_%', 'valence_%', 'energy_%', 'acousticness_%', 'instrumentalness_%', 'liveness_%', 'speechiness_%']

# %%
print(df)
# Out:
#                               track_name      artist(s)_name  artist_count  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook             2
# 1                                   LALA         Myke Towers             1
# 2                                vampire      Olivia Rodrigo             1
# 3                           Cruel Summer        Taylor Swift             1
# 4                         WHERE SHE GOES           Bad Bunny             1
# ..                                   ...                 ...           ...
# 948                         My Mind & Me        Selena Gomez             1
# 949            Bigger Than The Whole Sky        Taylor Swift             1
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951                        En La De Ella  Feid, Sech, Jhayco             3
# 952                                Alone           Burna Boy             1
#
# ...

# %%
print("Checking for missing values")
# print(df[df[0,:] == " "])
# indexing by its positon
# print(df.iloc[0])
print(df[columns[0]],end='\n')
# Out:
# Checking for missing values
# 0      Seven (feat. Latto) (Explicit Ver.)
# 1                                     LALA
# 2                                  vampire
# 3                             Cruel Summer
# 4                           WHERE SHE GOES
#                       ...
# 948                           My Mind & Me
# 949              Bigger Than The Whole Sky
# 950                   A Veces (feat. Feid)
# 951                          En La De Ella
# 952                                  Alone
# Name: track_name, Length: 953, dtype: object

# %%
print('isolating one row using .. .. .. . ... .')
df[df.index == 3]
# isolating two or more row
df[df.index.isin(range(0,10))]
# Out:
# isolating one row using .. .. .. . ... .
#                             track_name              artist(s)_name  \
# 0  Seven (feat. Latto) (Explicit Ver.)            Latto, Jung Kook
# 1                                 LALA                 Myke Towers
# 2                              vampire              Olivia Rodrigo
# 3                         Cruel Summer                Taylor Swift
# 4                       WHERE SHE GOES                   Bad Bunny
# 5                             Sprinter           Dave, Central Cee
# 6                      Ella Baila Sola  Eslabon Armado, Peso Pluma
# 7                             Columbia                     Quevedo
# 8                             fukumean                       Gunna
# 9                      La Bebe - Remix       Peso Pluma, Yng Lvcas
#
#    artist_count  released_year  released_month  released_day  \
# 0             2           2023               7            14
# 1             1           2023               3            23
# ...

# %%
# if we want to fetch the specific row by labels then we use loc[]
# otherwise if we want to fetch row by using index .iloc[]
# The 1 represents the row index (label)
print("accessing the data using labels..")
df.loc[0][:4]
# Out:
# accessing the data using labels..
# track_name        Seven (feat. Latto) (Explicit Ver.)
# artist(s)_name                       Latto, Jung Kook
# artist_count                                        2
# released_year                                    2023
# Name: 0, dtype: object

# %%
# df.iloc[0,:5]
print(df.iloc[100:110,0])
# Out:
# 100                                                Lover
# 101    Too Many Nights (feat. Don Toliver & with Future)
# 102                                             Chemical
# 103                                          Mockingbird
# 104                                            New Jeans
# 105                                         Primera Cita
# 106                              Cold Heart - PNAU Remix
# 107                                           Dandelions
# 108                                                Bones
# 109                                 Set Fire to the Rain
# Name: track_name, dtype: object

# %%
df.loc[100:110,columns[0:3]]
# Out:
#                                             track_name  \
# 100                                              Lover
# 101  Too Many Nights (feat. Don Toliver & with Future)
# 102                                           Chemical
# 103                                        Mockingbird
# 104                                          New Jeans
# 105                                       Primera Cita
# 106                            Cold Heart - PNAU Remix
# 107                                         Dandelions
# 108                                              Bones
# 109                               Set Fire to the Rain
# 110                                        Money Trees
#
#                         artist(s)_name  artist_count
# 100                       Taylor Swift             1
# 101  Future, Metro Boomin, Don Toliver             3
# 102                        Post Malone             1
# 103                             Eminem             1
# ...

# %%
df.loc[df['artist_count'] > 2,['artist(s)_name','artist_count']]
# Out:
#                                         artist(s)_name  artist_count
# 20            Gabito Ballesteros, Junior H, Peso Pluma             3
# 24                  The Weeknd, Madonna, Playboi Carti             3
# 32                 The Weeknd, 21 Savage, Metro Boomin             3
# 35   Big One, Duki, Lit Killah, Maria Becerra, FMK,...             8
# 43                      Tyler, The Creator, Kali Uchis             3
# ..                                                 ...           ...
# 920  Fran C, Polima WestCoast, Nickoog Clk, Pablito...             4
# 929                                 Luciano, Aitch, B�             3
# 930                 MC Ryan SP, Love Funk, Mc Paiva ZS             3
# 932                     Drake, Travis Scott, 21 Savage             3
# 951                                 Feid, Sech, Jhayco             3
#
# [112 rows x 2 columns]

# %%
# cleaning the data using pandas

print("sum of all null elements")
print(df.isnull().sum())
# Out:
# sum of all null elements
# track_name               0
# artist(s)_name           0
# artist_count             0
# released_year            0
# released_month           0
# released_day             0
# in_spotify_playlists     0
# in_spotify_charts        0
# streams                  0
# in_apple_playlists       0
# in_apple_charts          0
# in_deezer_playlists      0
# in_deezer_charts         0
# in_shazam_charts        50
# bpm                      0
# key                     95
# mode                     0
# danceability_%           0
# valence_%                0
# energy_%                 0
# acousticness_%           0
# instrumentalness_%       0
# liveness_%               0
# speechiness_%            0
# dtype: int64

# %%
# one way to deal with missing value is drop the missing values
df3 = df.copy()
print(df3.shape)
# Out:
# (953, 24)

# %%
df3.dropna(inplace=True,axis=1,how='any')
print(df3.shape)
df3.head()
# Out:
# (817, 24)
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts    streams  in_apple_playlists  ...  bpm key   mode  \
# ...

# %%
# dealing with missing values by replacing missing values...
print('replacing missing value with mean of row or column..')
df4 = df.copy()
print(df4.info())

# %%
lin_dat = pd.read_csv('insurance.csv')
lin_dat.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
print('how many null rows in dataframe')
lin_dat['age'][:3] = np.nan
lin_dat.loc[0][1]
# Out:
# how many null rows in dataframe
# C:\Users\pranj\AppData\Local\Temp\ipykernel_13024\1926193608.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lin_dat['age'][:3] = np.nan
# C:\Users\pranj\AppData\Local\Temp\ipykernel_13024\1926193608.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   lin_dat.loc[0][1]
# 'female'

# %%
lin_dat.isna()
df4 = lin_dat.copy()
df4.dropna(axis=0,inplace=True,how='any')
df4.head()
# Out:
#     age     sex     bmi  children smoker     region      charges
# 3  33.0    male  22.705         0     no  northwest  21984.47061
# 4  32.0    male  28.880         0     no  northwest   3866.85520
# 5  31.0  female  25.740         0     no  southeast   3756.62160
# 6  46.0  female  33.440         1     no  southeast   8240.58960
# 7  37.0  female  27.740         3     no  northwest   7281.50560

# %%
mean = lin_dat['age'].mean()
lin_dat.fillna(mean,inplace=True)

# %%
duplicate = lin_dat[['age','sex']][:4]
duplicate2 = lin_dat[['age','sex']][5:6]
lin_dat1 = pd.concat([duplicate,duplicate2])
lin_dat1.head()
# Out:
#          age     sex
# 0  39.246442  female
# 1  39.246442    male
# 2  39.246442    male
# 3  33.000000    male
# 5  31.000000  female

# %%
lin_dat1.drop_duplicates(inplace=True)
print(lin_dat1.shape)
lin_dat1.head()
# Out:
# (4, 2)
#          age     sex
# 0  39.246442  female
# 1  39.246442    male
# 3  33.000000    male
# 5  31.000000  female
